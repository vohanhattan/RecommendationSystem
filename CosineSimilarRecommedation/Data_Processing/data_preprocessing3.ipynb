# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Movie 2020

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
del df['.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.']

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 267  DECEMBER         25       We Can Be Heroes
# 268  DECEMBER         25      News of the World
# 269  DECEMBER         25  One Night in Miami...
# 270  DECEMBER         25  Promising Young Woman
# 271  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 267                     Netflix / Troublemaker Studios
# 268        Universal Pictures / Perfect World Pictures
# 269                                     Amazon Studios
# 270          Focus Features / FilmNation Entertainment
# 271                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    NaN
# 1    William Eubank (director); Brian Duffield, Ada...    NaN
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    NaN
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    NaN
# ..                                                 ...    ...
# 267  Robert Rodriguez (director/screenplay); Priyan...  [240]
# 268  Paul Greengrass (director/screenplay); Luke Da...  [241]
# 269  Regina King (director); Kemp Powers (screenpla...  [242]
# 270  Emerald Fennell (director/screenplay); Carey M...  [243]
# 271  Kornél Mundruczó (director); Kata Wéber (scree...  [244]
#
# [272 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
#df_2020.to_csv('check1.csv',index=False)
df_2020=pd.read_csv('check1.csv')
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#      genres
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 267     NaN
# 268     NaN
# 269     NaN
# 270     NaN
# 271     NaN
#
# [272 rows x 3 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\vohan\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\vohan\anaconda3\lib\site-packages (from tmdbv3api) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vohan\anaconda3\lib\site-packages (from requests->tmdbv3api) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vohan\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vohan\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vohan\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'b7e7aeea608257af93a032205bfada32'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
result = tmdb_movie.search("shang chi")
result
# Out:
# [{'adult': False, 'backdrop_path': '/uizrxdqIl1a4c9UIhSdPM3o6u0f.jpg', 'genre_ids': [28, 12, 14], 'id': 566525, 'original_language': 'en', 'original_title': 'Shang-Chi and the Legend of the Ten Rings', 'overview': 'Shang-Chi must confront the past he thought he left behind when he is drawn into the web of the mysterious Ten Rings organization.', 'popularity': 2218.744, 'poster_path': '/xeItgLK9qcafxbd8kYgv7XnMEog.jpg', 'release_date': '2021-09-01', 'title': 'Shang-Chi and the Legend of the Ten Rings', 'video': False, 'vote_average': 7.9, 'vote_count': 946}]

# %%
i=0
result=[]
from tmdbv3api import Movie
tmdb_movie = Movie()
for x in df_2020['Title']:
    result.append(tmdb_movie.search(x))
    #print(result[i])
for i in range(0,272):
    print(result[i][0].id)
    i=i+1
    print(i)
# Out:
# 1970
# 1
# 443791
# 2
# 526019
# 3
# 418533
# 4
# 634904
# 5
# 477036
# 6
# 527534
# 7
# 38700
# 8
# 448119
# 9
# 651070
# 10
# 522627
# 11
# 492611
# 12
# 442065
# 13
# 547565
# 14
# 658199
# 15
# 466622
# 16
# 542224
# 17
# 627463
# 18
# 495764
# 19
# 474764
# 20
# 550440
# 21
# 653601
# 22
# 565426
# 23
# 454626
# 24
# 539537
# 25
# 589049
# 26
# 560391
# 27
# 663255
# 28
# 520390
# 29
# 481848
# 30
# 505225
# 31
# 555974
# 32
# 526007
# 33
# 566927
# 34
# 570670
# 35
# 342470
# 36
# 399363
# 37
# 457335
# 38
# 508439
# 39
# 529485
# 40
# 581600
# 41
# 627725
# 42
# 566872
# 43
# 586461
# 44
# 558582
# 45
# 338762
# 46
# 514847
# 47
# 585244
# 48
# 567970
# 49
# 382748
# 50
# 567714
# 51
# 595671
# 52
# 539617
# 53
# 535987
# 54
# 491926
# 55
# 660609
# 56
# 458305
# 57
# 615177
# 58
# 446893
# 59
# 624808
# 60
# 637157
# 61
# 546724
# 62
# 686142
# 63
# 684420
# 64
# 653744
# 65
# 560044
# 66
# 545609
# 67
# 693594
# 68
# 530723
# 69
# 689723
# 70
# 530956
# 71
# 605804
# 72
# 597219
# 73
# 560204
# 74
# 482273
# 75
# 429422
# 76
# 582596
# 77
# 385103
# 78
# 691812
# 79
# 513268
# 80
# 576156
# 81
# 602147
# 82
# 686245
# 83
# 665824
# 84
# 606679
# 85
# 547017
# 86
# 339095
# 87
# 601844
# 88
# 513584
# 89
# 581859
# 90
# 475430
# 91
# 579583
# 92
# 702936
# 93
# 514593
# 94
# 451184
# 95
# 707886
# 96
# 509585
# 97
# 684700
# 98
# 531454
# 99
# 595148
# 100
# 592834
# 101
# 556574
# 102
# 539181
# 103
# 706510
# 104
# 547016
# 105
# 516486
# 106
# 587792
# 107
# 714375
# 108
# 603119
# 109
# 718840
# 110
# 608195
# 111
# 315064
# 112
# 583083
# 113
# 587496
# 114
# 703745
# 115
# 719643
# 116
# 550231
# 117
# 523977
# 118
# 664297
# 119
# 628917
# 120
# 531499
# 121
# 505707
# 122
# 605116
# 123
# 454433
# 124
# 653723
# 125
# 653598
# 126
# 400160
# 127
# 508570
# 128
# 625568
# 129
# 517412
# 130
# 493065
# 131
# 523781
# 132
# 724989
# 133
# 621013
# 134
# 577922
# 135
# 501979
# 136
# 340102
# 137
# 520900
# 138
# 500840
# 139
# 594328
# 140
# 615466
# 141
# 825997
# 142
# 680028
# 143
# 647265
# 144
# 644090
# 145
# 337401
# 146
# 665877
# 147
# 659986
# 148
# 594084
# 149
# 623491
# 150
# 632666
# 151
# 499932
# 152
# 616251
# 153
# 611114
# 154
# 707408
# 155
# 726739
# 156
# 615115
# 157
# 627290
# 158
# 545237
# 159
# 536396
# 160
# 479259
# 161
# 803708
# 162
# 497582
# 163
# 556984
# 164
# 539885
# 165
# 541305
# 166
# 653606
# 167
# 621870
# 168
# 664498
# 169
# 733156
# 170
# 597156
# 171
# 519056
# 172
# 575417
# 173
# 604578
# 174
# 567971
# 175
# 435615
# 176
# 595149
# 177
# 481848
# 178
# 660982
# 179
# 539649
# 180
# 716258
# 181
# 617505
# 182
# 715123
# 183
# 552532
# 184
# 425001
# 185
# 475303
# 186
# 593427
# 187
# 620897
# 188
# 643550
# 189
# 732713
# 190
# 624963
# 191
# 590223
# 192
# 553604
# 193
# 630566
# 194
# 507712
# 195
# 720755
# 196
# 509635
# 197
# 710356
# 198
# 664184
# 199
# 670266
# 200
# 531219
# 201
# 560050
# 202
# 740985
# 203
# 613504
# 204
# 516632
# 205
# 549294
# 206
# 10823
# 207
# 317198
# 208
# 524840
# 209
# 590995
# 210
# 615665
# 211
# 571384
# 212
# 575774
# 213
# 621151
# 214
# 556501
# 215
# 596161
# 216
# 466081
# 217
# 680593
# 218
# 592984
# 219
# 614560
# 220
# 551804
# 221
# 622855
# 222
# 480434
# 223
# 602211
# 224
# 667869
# 225
# 595931
# 226
# 682377
# 227
# 643882
# 228
# 546121
# 229
# 502033
# 230
# 622977
# 231
# 590706
# 232
# 472815
# 233
# 529203
# 234
# 520172
# 235
# 615667
# 236
# 654028
# 237
# 634544
# 238
# 768141
# 239
# 521007
# 240
# 447362
# 241
# 526702
# 242
# 611213
# 243
# 632322
# 244
# 662546
# 245
# 652962
# 246
# 646593
# 247
# 624788
# 248
# 623856
# 249
# 614911
# 250
# 721625
# 251
# 628333
# 252
# 727306
# 253
# 540023
# 254
# 643612
# 255
# 633908
# 256
# 727097
# 257
# 653665
# 258
# 458576
# 259
# 524047
# 260
# 549514
# 261
# 560144
# 262
# 759902
# 263
# 774372
# 264
# 584288
# 265
# 464052
# 266
# 508442
# 267
# 615677
# 268
# 581032
# 269
# 661914
# 270
# 582014
# 271
# 641662
# 272

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 267            Action Fantasy Family Comedy
# 268                       Adventure Western
# 269                                   Drama
# 270                    Thriller Crime Drama
# 271                                   Drama
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 267       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 268      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 269  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 270  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 271      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 267            Action Fantasy Family Comedy  Robert Rodriguez
# 268                       Adventure Western   Paul Greengrass
# 269                                   Drama       Regina King
# 270                    Thriller Crime Drama   Emerald Fennell
# 271                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 267  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 268              Tom Hanks      Helena Zengel              NaN
# 269      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 270         Carey Mulligan         Bo Burnham      Alison Brie
# 271          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [272 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 267  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 268   Paul Greengrass              Tom Hanks      Helena Zengel
# 269       Regina King      Kingsley Ben-Adir          Eli Goree
# 270   Emerald Fennell         Carey Mulligan         Bo Burnham
# 271  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 267    YaYa Gosselin            Action Fantasy Family Comedy
# 268              NaN                       Adventure Western
# 269      Aldis Hodge                                   Drama
# 270      Alison Brie                    Thriller Crime Drama
# 271     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 267       We Can Be Heroes
# 268      News of the World
# 269  One Night in Miami...
# 270  Promising Young Woman
# 271      Pieces of a Woman
#
# [272 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-323-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 266       Pete Docter             Jamie Foxx           Tina Fey
# 267  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 269       Regina King      Kingsley Ben-Adir          Eli Goree
# 270   Emerald Fennell         Carey Mulligan         Bo Burnham
# 271  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 266    Graham Norton   Family Animation Music Comedy Fantasy
# 267    YaYa Gosselin            Action Fantasy Family Comedy
# 269      Aldis Hodge                                   Drama
# 270      Alison Brie                    Thriller Crime Drama
# 271     Molly Parker                                   Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 266                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 267       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 269  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 270  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 271      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [245 rows x 7 columns]

# %% [markdown]
# ## Movie 2021

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
del df['.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.']

# %%
df2
# Out:
#    Opening  Opening.1                              Title  \
# 0    APRIL          2                    Concrete Cowboy
# 1    APRIL          2                         The Unholy
# 2    APRIL          2              Every Breath You Take
# 3    APRIL          2                         Shiva Baby
# 4    APRIL          2  The Girl Who Believes in Miracles
# ..     ...        ...                                ...
# 81    JUNE         25            Mary J. Blige's My Life
# 82    JUNE         25                             Fathom
# 83    JUNE         25                            Rollers
# 84    JUNE         30        America: The Motion Picture
# 85    JUNE         30                               Zola
#
#                     Production company  \
# 0                              Netflix
# 1   Screen Gems / Ghost House Pictures
# 2               Vertical Entertainment
# 3                               Utopia
# 4           Atlas Distribution Company
# ..                                 ...
# 81                      Amazon Studios
# 82                           Apple TV+
# 83              Level 33 Entertainment
# 84  Netflix / Floyd County Productions
# 85                                 A24
#
#                                         Cast and crew   Ref.
# 0   Ricky Staub (director/screenplay); Dan Walser ...   [53]
# 1   Evan Spiliotopoulos (director/screenplay); Jef...   [54]
# 2   Vaughn Stein (director); David Murray (screenp...   [55]
# 3   Emma Seligman (director/screenplay); Rachel Se...    NaN
# 4   Richard Correll (director/screenplay); G.M. Me...    NaN
# ..                                                ...    ...
# 81  Vanessa Roth (director/screenplay); Mary J. Bl...    NaN
# 82  Drew Xanthopoulos (director/screenplay); Miche...    NaN
# 83  Isaiah Smallman (director); Johnny Ray Gill, K...    NaN
# 84  Matt Thompson (director); Dave Callaham (scree...    NaN
# 85  Janicza Bravo (director/screenplay); Jeremy O....  [104]
#
# [86 rows x 6 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                                         Title  \
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 319                  The Matrix Resurrections
# 320                                    Sing 2
# 321                            The King's Man
# 322  American Underdog: The Kurt Warner Story
# 323                                    Cyrano
#
#                                          Cast and crew
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 319  Lana Wachowski (director/screenplay); David Mi...
# 320  Garth Jennings (director/screenplay); Matthew ...
# 321  Matthew Vaughn (director/screenplay); Karl Gaj...
# 322  Erwin brothers (directors); David Aaron, Jon E...
# 323  Joe Wright (director); Erica Schmidt (screenpl...
#
# [324 rows x 2 columns]

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-374-252c1cda1e49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                                         Title  \
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 319                  The Matrix Resurrections
# 320                                    Sing 2
# 321                            The King's Man
# 322  American Underdog: The Kurt Warner Story
# 323                                    Cyrano
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 319  Lana Wachowski (director/screenplay); David Mi...
# 320  Garth Jennings (director/screenplay); Matthew ...
# 321  Matthew Vaughn (director/screenplay); Karl Gaj...
# 322  Erwin brothers (directors); David Aaron, Jon E...
# 323  Joe Wright (director); Erica Schmidt (screenpl...
#
#                                         genres
# 0                            Horror Action War
# 1                                  Crime Drama
# 2                           Comedy Crime Drama
# 3                                Drama History
# 4              Thriller Action Science Fiction
# ..                                         ...
# 319  Action Adventure Thriller Science Fiction
# 320        Family Comedy Animation Drama Music
# 321              War Action Thriller Adventure
# 322                                      Drama
# 323               Drama Comedy History Romance
#
# [324 rows x 3 columns]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                                         Title  \
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 319                  The Matrix Resurrections
# 320                                    Sing 2
# 321                            The King's Man
# 322  American Underdog: The Kurt Warner Story
# 323                                    Cyrano
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 319  Lana Wachowski (director/screenplay); David Mi...
# 320  Garth Jennings (director/screenplay); Matthew ...
# 321  Matthew Vaughn (director/screenplay); Karl Gaj...
# 322  Erwin brothers (directors); David Aaron, Jon E...
# 323  Joe Wright (director); Erica Schmidt (screenpl...
#
#                                         genres    director_name  \
# 0                            Horror Action War   Roseanne Liang
# 1                                  Crime Drama    Ramin Bahrani
# 2                           Comedy Crime Drama       Doug Liman
# 3                                Drama History      Simon Stone
# 4              Thriller Action Science Fiction  Mikael Håfström
# ..                                         ...              ...
# 319  Action Adventure Thriller Science Fiction   Lana Wachowski
# 320        Family Comedy Animation Drama Music   Garth Jennings
# 321              War Action Thriller Adventure   Matthew Vaughn
# 322                                      Drama   Erwin brothers
# 323               Drama Comedy History Romance       Joe Wright
#
#             actor_1_name       actor_2_name           actor_3_name
# 0     Chloë Grace Moretz  Taylor John Smith           Beulah Koale
# 1          Adarsh Gourav      Rajkummar Rao  Priyanka Chopra Jonas
# 2          Anne Hathaway   Chiwetel Ejiofor       Stephen Merchant
# 3         Carey Mulligan      Ralph Fiennes             Lily James
# 4         Anthony Mackie       Damson Idris          Emily Beecham
# ..                   ...                ...                    ...
# 319         Keanu Reeves   Carrie-Anne Moss  Yahya Abdul-Mateen II
# 320  Matthew McConaughey  Reese Witherspoon     Scarlett Johansson
# 321        Ralph Fiennes     Gemma Arterton             Rhys Ifans
# 322         Zachary Levi        Anna Paquin       Ser'Darius Blain
# 323       Peter Dinklage      Haley Bennett    Kelvin Harrison Jr.
#
# [324 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#        director_name         actor_1_name       actor_2_name  \
# 0     Roseanne Liang   Chloë Grace Moretz  Taylor John Smith
# 1      Ramin Bahrani        Adarsh Gourav      Rajkummar Rao
# 2         Doug Liman        Anne Hathaway   Chiwetel Ejiofor
# 3        Simon Stone       Carey Mulligan      Ralph Fiennes
# 4    Mikael Håfström       Anthony Mackie       Damson Idris
# ..               ...                  ...                ...
# 319   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 320   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 321   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 322   Erwin brothers         Zachary Levi        Anna Paquin
# 323       Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                     genres  \
# 0             Beulah Koale                          Horror Action War
# 1    Priyanka Chopra Jonas                                Crime Drama
# 2         Stephen Merchant                         Comedy Crime Drama
# 3               Lily James                              Drama History
# 4            Emily Beecham            Thriller Action Science Fiction
# ..                     ...                                        ...
# 319  Yahya Abdul-Mateen II  Action Adventure Thriller Science Fiction
# 320     Scarlett Johansson        Family Comedy Animation Drama Music
# 321             Rhys Ifans              War Action Thriller Adventure
# 322       Ser'Darius Blain                                      Drama
# 323    Kelvin Harrison Jr.               Drama Comedy History Romance
#
#                                   movie_title
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 319                  The Matrix Resurrections
# 320                                    Sing 2
# 321                            The King's Man
# 322  American Underdog: The Kurt Warner Story
# 323                                    Cyrano
#
# [324 rows x 6 columns]

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
# Out:
# <ipython-input-393-6e765124d575>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21
# Out:
#        director_name         actor_1_name       actor_2_name  \
# 0     Roseanne Liang   Chloë Grace Moretz  Taylor John Smith
# 1      Ramin Bahrani        Adarsh Gourav      Rajkummar Rao
# 2         Doug Liman        Anne Hathaway   Chiwetel Ejiofor
# 3        Simon Stone       Carey Mulligan      Ralph Fiennes
# 4    Mikael Håfström       Anthony Mackie       Damson Idris
# ..               ...                  ...                ...
# 319   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 320   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 321   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 322   Erwin brothers         Zachary Levi        Anna Paquin
# 323       Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                     genres  \
# 0             Beulah Koale                          Horror Action War
# 1    Priyanka Chopra Jonas                                Crime Drama
# 2         Stephen Merchant                         Comedy Crime Drama
# 3               Lily James                              Drama History
# 4            Emily Beecham            Thriller Action Science Fiction
# ..                     ...                                        ...
# 319  Yahya Abdul-Mateen II  Action Adventure Thriller Science Fiction
# 320     Scarlett Johansson        Family Comedy Animation Drama Music
# 321             Rhys Ifans              War Action Thriller Adventure
# 322       Ser'Darius Blain                                      Drama
# 323    Kelvin Harrison Jr.               Drama Comedy History Romance
#
#                                   movie_title  \
# 0                         shadow in the cloud
# 1                             the white tiger
# 2                                 locked down
# 3                                     the dig
# 4                            outside the wire
# ..                                        ...
# 319                  the matrix resurrections
# 320                                    sing 2
# 321                            the king's man
# 322  american underdog: the kurt warner story
# 323                                    cyrano
#
#                                                   comb
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3    Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4    Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                                                 ...
# 319  Keanu Reeves Carrie-Anne Moss Yahya Abdul-Mate...
# 320  Matthew McConaughey Reese Witherspoon Scarlett...
# 321  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 322  Zachary Levi Anna Paquin Ser'Darius Blain Erwi...
# 323  Peter Dinklage Haley Bennett Kelvin Harrison J...
#
# [302 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                 director_name       actor_1_name          actor_2_name  \
# 0               John Lasseter          Tom Hanks             Tim Allen
# 1                Joe Johnston     Robin Williams         Jonathan Hyde
# 2               Howard Deutch     Walter Matthau           Jack Lemmon
# 3             Forest Whitaker    Whitney Houston        Angela Bassett
# 4               Charles Shyer       Steve Martin          Diane Keaton
# ...                       ...                ...                   ...
# 39656  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 39657            Greta Gerwig      Saoirse Ronan           Emma Watson
# 39658              Sam Mendes      George MacKay  Dean-Charles Chapman
# 39659   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 39660         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0         Don Rickles                   Animation Comedy Family
# 1       Kirsten Dunst                  Adventure Fantasy Family
# 2         Ann-Margret                            Romance Comedy
# 3      Loretta Devine                      Comedy Drama Romance
# 4        Martin Short                                    Comedy
# ...               ...                                       ...
# 39656   Rashida Jones  Animation Action Adventure Comedy Family
# 39657   Florence Pugh                             Drama Romance
# 39658     Mark Strong                 War Drama Action Thriller
# 39659     Brie Larson                       Drama Crime History
# 39660     Aldis Hodge                                     Drama
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 39656            spies in disguise
# 39657                 little women
# 39658                         1917
# 39659                   just mercy
# 39660                     clemency
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 39656  Will Smith Tom Holland Rashida Jones Nick Brun...
# 39657  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 39658  George MacKay Dean-Charles Chapman Mark Strong...
# 39659  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 39660  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [39661 rows x 7 columns]

# %%
final_df = old_df.append(new_df20.append(new_df21,ignore_index=True),ignore_index=True)

# %%
final_df
# Out:
#          director_name         actor_1_name       actor_2_name  \
# 0        John Lasseter            Tom Hanks          Tim Allen
# 1         Joe Johnston       Robin Williams      Jonathan Hyde
# 2        Howard Deutch       Walter Matthau        Jack Lemmon
# 3      Forest Whitaker      Whitney Houston     Angela Bassett
# 4        Charles Shyer         Steve Martin       Diane Keaton
# ...                ...                  ...                ...
# 40203   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 40204   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 40205   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 40206   Erwin brothers         Zachary Levi        Anna Paquin
# 40207       Joe Wright       Peter Dinklage      Haley Bennett
#
#                 actor_3_name                                     genres  \
# 0                Don Rickles                    Animation Comedy Family
# 1              Kirsten Dunst                   Adventure Fantasy Family
# 2                Ann-Margret                             Romance Comedy
# 3             Loretta Devine                       Comedy Drama Romance
# 4               Martin Short                                     Comedy
# ...                      ...                                        ...
# 40203  Yahya Abdul-Mateen II  Action Adventure Thriller Science Fiction
# 40204     Scarlett Johansson        Family Comedy Animation Drama Music
# 40205             Rhys Ifans              War Action Thriller Adventure
# 40206       Ser'Darius Blain                                      Drama
# 40207    Kelvin Harrison Jr.               Drama Comedy History Romance
#
#                                     movie_title  \
# 0                                     toy story
# 1                                       jumanji
# 2                              grumpier old men
# 3                             waiting to exhale
# 4                   father of the bride part ii
# ...                                         ...
# 40203                  the matrix resurrections
# 40204                                    sing 2
# 40205                            the king's man
# 40206  american underdog: the kurt warner story
# 40207                                    cyrano
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 40203  Keanu Reeves Carrie-Anne Moss Yahya Abdul-Mate...
# 40204  Matthew McConaughey Reese Witherspoon Scarlett...
# 40205  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 40206  Zachary Levi Anna Paquin Ser'Darius Blain Erwi...
# 40207  Peter Dinklage Haley Bennett Kelvin Harrison J...
#
# [40208 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
