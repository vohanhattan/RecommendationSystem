# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Movie 2022

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#      Opening  Opening.1                         Title  \
# 0    JANUARY          7                       The 355
# 1    JANUARY         14                        Scream
# 2    JANUARY         14                    Deep Water
# 3    JANUARY         14          The Man from Toronto
# 4    JANUARY         21                     Five Eyes
# ..       ...        ...                           ...
# 62  DECEMBER         16                      Avatar 2
# 63  DECEMBER         16  Aquaman and the Lost Kingdom
# 64  DECEMBER         23   I Wanna Dance with Somebody
# 65  DECEMBER         23               The Nightingale
# 66  DECEMBER         25                       Babylon
#
#                                    Production company  \
# 0   Universal Pictures / Perfect World Pictures / ...
# 1           Paramount Pictures / Spyglass Media Group
# 2          20th Century Studios / Regency Enterprises
# 3   Columbia Pictures / Bron Creative / Escape Art...
# 4                                  STXfilms / Miramax
# ..                                                ...
# 62    20th Century Studios / Lightstorm Entertainment
# 63  Warner Bros. Pictures / DC Films / Atomic Mons...
# 64                                   TriStar Pictures
# 65                                   TriStar Pictures
# 66                                 Paramount Pictures
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 2   Adrian Lyne (director); Zach Helm, Sam Levinso...
# 3   Patrick Hughes (director); Robbie Fox (screenp...
# 4   Guy Ritchie (director); Ivan Atkinson, Marn Da...
# ..                                                ...
# 62  James Cameron (director/screenplay); Josh Frie...
# 63  James Wan (director), David Leslie Johnson-McG...
# 64  Kasi Lemmons (director); Anthony McCarten (scr...
# 65  Mélanie Laurent (director), Dana Stevens (scre...
# 66  Damien Chazelle (director/screenplay); Brad Pi...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                 [1]
# 1                                                 [2]
# 2                                                 [3]
# 3                                                 [4]
# 4                                                 [5]
# ..                                                ...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
#
#     Ref.
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 62  [53]
# 63  [54]
# 64  [55]
# 65  [56]
# 66  [57]
#
# [67 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
df_2022=pd.read_csv('check2.csv')
df_2022
# Out:
#                            Title  \
# 0                        The 355
# 1                         Scream
# 2                     Deep Water
# 3           The Man from Toronto
# 4                      Five Eyes
# ..                           ...
# 61                      Avatar 2
# 62  Aquaman and the Lost Kingdom
# 63   I Wanna Dance with Somebody
# 64               The Nightingale
# 65                       Babylon
#
#                                         Cast and crew
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 2   Adrian Lyne (director); Zach Helm, Sam Levinso...
# 3   Patrick Hughes (director); Robbie Fox (screenp...
# 4   Guy Ritchie (director); Ivan Atkinson, Marn Da...
# ..                                                ...
# 61  James Cameron (director/screenplay); Josh Frie...
# 62  James Wan (director), David Leslie Johnson-McG...
# 63  Kasi Lemmons (director); Anthony McCarten (scr...
# 64  Mélanie Laurent (director), Dana Stevens (scre...
# 65  Damien Chazelle (director/screenplay); Brad Pi...
#
# [66 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'b7e7aeea608257af93a032205bfada32'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                            Title  \
# 0                        The 355
# 1                         Scream
# 2                     Deep Water
# 3           The Man from Toronto
# 4                      Five Eyes
# ..                           ...
# 61                      Avatar 2
# 62  Aquaman and the Lost Kingdom
# 63   I Wanna Dance with Somebody
# 64               The Nightingale
# 65                       Babylon
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 2   Adrian Lyne (director); Zach Helm, Sam Levinso...
# 3   Patrick Hughes (director); Robbie Fox (screenp...
# 4   Guy Ritchie (director); Ivan Atkinson, Marn Da...
# ..                                                ...
# 61  James Cameron (director/screenplay); Josh Frie...
# 62  James Wan (director), David Leslie Johnson-McG...
# 63  Kasi Lemmons (director); Anthony McCarten (scr...
# 64  Mélanie Laurent (director), Dana Stevens (scre...
# 65  Damien Chazelle (director/screenplay); Brad Pi...
#
#                                        genres
# 0                             Action Thriller
# 1                        Crime Horror Mystery
# 2                      Thriller Romance Drama
# 3                              Romance Comedy
# 4                             Action Thriller
# ..                                        ...
# 61   Action Adventure Science Fiction Fantasy
# 62                   Adventure Action Fantasy
# 63                                      Drama
# 64                             Drama Thriller
# 65  Action Adventure Science Fiction Thriller
#
# [66 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                            Title  \
# 0                        The 355
# 1                         Scream
# 2                     Deep Water
# 3           The Man from Toronto
# 4                      Five Eyes
# ..                           ...
# 61                      Avatar 2
# 62  Aquaman and the Lost Kingdom
# 63   I Wanna Dance with Somebody
# 64               The Nightingale
# 65                       Babylon
#
#                                         Cast and crew  \
# 0   Simon Kinberg (director/screenplay); Theresa R...
# 1   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 2   Adrian Lyne (director); Zach Helm, Sam Levinso...
# 3   Patrick Hughes (director); Robbie Fox (screenp...
# 4   Guy Ritchie (director); Ivan Atkinson, Marn Da...
# ..                                                ...
# 61  James Cameron (director/screenplay); Josh Frie...
# 62  James Wan (director), David Leslie Johnson-McG...
# 63  Kasi Lemmons (director); Anthony McCarten (scr...
# 64  Mélanie Laurent (director), Dana Stevens (scre...
# 65  Damien Chazelle (director/screenplay); Brad Pi...
#
#                                        genres  \
# 0                             Action Thriller
# 1                        Crime Horror Mystery
# 2                      Thriller Romance Drama
# 3                              Romance Comedy
# 4                             Action Thriller
# ..                                        ...
# 61   Action Adventure Science Fiction Fantasy
# 62                   Adventure Action Fantasy
# 63                                      Drama
# 64                             Drama Thriller
# 65  Action Adventure Science Fiction Thriller
#
#                            director_name      actor_1_name     actor_2_name  \
# 0                          Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1   Matt Bettinelli-Olpin, Tyler Gillett     Neve Campbell   David Arquette
# 2                            Adrian Lyne       Ben Affleck     Ana de Armas
# 3                         Patrick Hughes        Kevin Hart  Woody Harrelson
# 4                            Guy Ritchie     Jason Statham     Aubrey Plaza
# ..                                   ...               ...              ...
# 61                         James Cameron   Sam Worthington      Zoe Saldana
# 62                             James Wan       Jason Momoa      Amber Heard
# 63                          Kasi Lemmons       Naomi Ackie   Ashton Sanders
# 64                       Mélanie Laurent    Dakota Fanning     Elle Fanning
# 65                       Damien Chazelle         Brad Pitt    Margot Robbie
#
#            actor_3_name
# 0         Penélope Cruz
# 1         Courteney Cox
# 2           Tracy Letts
# 3           Kaley Cuoco
# 4          Bugzy Malone
# ..                  ...
# 61         Stephen Lang
# 62       Patrick Wilson
# 63                  NaN
# 64                  NaN
# 65  Katherine Waterston
#
# [66 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                            director_name      actor_1_name     actor_2_name  \
# 0                          Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1   Matt Bettinelli-Olpin, Tyler Gillett     Neve Campbell   David Arquette
# 2                            Adrian Lyne       Ben Affleck     Ana de Armas
# 3                         Patrick Hughes        Kevin Hart  Woody Harrelson
# 4                            Guy Ritchie     Jason Statham     Aubrey Plaza
# ..                                   ...               ...              ...
# 61                         James Cameron   Sam Worthington      Zoe Saldana
# 62                             James Wan       Jason Momoa      Amber Heard
# 63                          Kasi Lemmons       Naomi Ackie   Ashton Sanders
# 64                       Mélanie Laurent    Dakota Fanning     Elle Fanning
# 65                       Damien Chazelle         Brad Pitt    Margot Robbie
#
#            actor_3_name                                     genres  \
# 0         Penélope Cruz                            Action Thriller
# 1         Courteney Cox                       Crime Horror Mystery
# 2           Tracy Letts                     Thriller Romance Drama
# 3           Kaley Cuoco                             Romance Comedy
# 4          Bugzy Malone                            Action Thriller
# ..                  ...                                        ...
# 61         Stephen Lang   Action Adventure Science Fiction Fantasy
# 62       Patrick Wilson                   Adventure Action Fantasy
# 63                  NaN                                      Drama
# 64                  NaN                             Drama Thriller
# 65  Katherine Waterston  Action Adventure Science Fiction Thriller
#
#                      movie_title
# 0                        The 355
# 1                         Scream
# 2                     Deep Water
# 3           The Man from Toronto
# 4                      Five Eyes
# ..                           ...
# 61                      Avatar 2
# 62  Aquaman and the Lost Kingdom
# 63   I Wanna Dance with Somebody
# 64               The Nightingale
# 65                       Babylon
#
# [66 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# <ipython-input-84-bd701421fe8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                                         director_name  \
# 0                                       Simon Kinberg
# 1                Matt Bettinelli-Olpin, Tyler Gillett
# 2                                         Adrian Lyne
# 3                                      Patrick Hughes
# 4                                         Guy Ritchie
# 5                                     Daniel Espinosa
# 6                                    Scott Derrickson
# 7                                     Roland Emmerich
# 8                                       Jeff Tremaine
# 9                                     Kenneth Branagh
# 10                                          Kat Coiro
# 11                                    Ruben Fleischer
# 12                                        Michael Bay
# 13                                      Hamish Grieve
# 16                                        Matt Reeves
# 18                                       Simon Curtis
# 19                                           Jon Gunn
# 20                                          Sam Raimi
# 21                                       David Leitch
# 22                                        Jeff Fowler
# 23                                      Robert Eggers
# 24                                        David Yates
# 25                                 Aaron and Adam Nee
# 26                                     Pierre Perifel
# 27                                       Tom Gormican
# 28                                      Taika Waititi
# 29                            Scott Beck, Bryan Woods
# 30                                        Jared Stern
# 32                                    Joseph Kosinski
# 33                                     Chad Stahelski
# 34                                     Loren Bouchard
# 35                                       Baz Luhrmann
# 36                                    Colin Trevorrow
# 38                                   Steven Caple Jr.
# 39                                        Jason Moore
# 40                                         Kyle Balda
# 41                                       Ryan Coogler
# 42                                       Jordan Peele
# 44                                      James Mangold
# 45                                 Jaume Collet-Serra
# 46                                     Gary Dauberman
# 49                                       Olivia Wilde
# 50                              Christopher McQuarrie
# 51                                          Ol Parker
# 52  Joaquim Dos Santos, Kemp Powers, Justin K. Tho...
# 53                                 David Gordon Green
# 54                                    Andy Muschietti
# 55                                        Nia DaCosta
# 56                                       Vicky Jenson
# 57                                     Maria Schrader
# 59                                  Michael B. Jordan
# 61                                      James Cameron
# 62                                          James Wan
# 65                                    Damien Chazelle
#
#                                 actor_1_name           actor_2_name  \
# 0                           Jessica Chastain         Lupita Nyong'o
# 1                              Neve Campbell         David Arquette
# 2                                Ben Affleck           Ana de Armas
# 11         Tati Gabrielle                     Adventure Action Drama Mystery
# 12          Eiza González              Action Horror Thriller Comedy Romance
# 13  Geraldine Viswanathan                            Family Comedy Animation
# 16              Paul Dano                                 Action Crime Drama
# 18       Michelle Dockery                                              Drama
# 19            Jacob Laval                                       Drama Family
# 20          Benedict Wong                    Fantasy Action Adventure Horror
# 21            Andrew Koji                                    Action Thriller
# 22           Tika Sumpter               Family Science Fiction Comedy Action
# 23        Anya Taylor-Joy                      Action Drama History Thriller
# 24             Dan Fogler                                            Fantasy
# 25         Patti Harrison                            Adventure Comedy Family
# 26          Anthony Ramos                                          Animation
# 27          Sharon Horgan                                             Comedy
# 28         Tessa Thompson    Action Adventure Fantasy Comedy Science Fiction
# 29          Chloe Coleman                                              Drama
# 30          Kate McKinnon                  Animation Adventure Family Comedy
# 32      Jennifer Connelly                                       Action Drama
# 33          Lance Reddick                              Action Crime Thriller
# 34              Dan Mintz                                   Comedy Animation
# 35         Olivia DeJonge                               Drama Comedy History
# 36              Sam Neill          Adventure Action Science Fiction Thriller
# 38      Luna Lauren Vélez                   Action Science Fiction Adventure
# 39            Sônia Braga                                      Comedy Action
# 40          Michelle Yeoh           Family Animation Action Adventure Comedy
# 41           Danai Gurira                   Action Adventure Science Fiction
# 42            Steven Yeun                                     Mystery Horror
# 44         Mads Mikkelsen                                   Action Adventure
# 45          Noah Centineo                           Action Fantasy Adventure
# 46         Makenzie Leigh                                             Horror
# 49           Olivia Wilde                                     Drama Thriller
# 50             Simon Pegg                          Action Adventure Thriller
# 51          Kaitlyn Dever                                     Comedy Romance
# 52       Hailee Steinfeld  Animation Action Science Fiction Comedy Adventure
# 53          Andi Matichak                                    Horror Thriller
# 54            Sasha Calle     Action Adventure Science Fiction Fantasy Drama
# 55           Iman Vellani           Action Adventure Science Fiction Fantasy
# 56       Elizabeth Martin                                        Documentary
# 57      Patricia Clarkson                         Comedy Crime Drama Mystery
# 59        Phylicia Rashad                                       Drama Action
# 61           Stephen Lang           Action Adventure Science Fiction Fantasy
# 62         Patrick Wilson                           Adventure Action Fantasy
# 65    Katherine Waterston          Action Adventure Science Fiction Thriller
#
#                                     movie_title  \
# 0                                       the 355
# 1                                        scream
# 2                                    deep water
# 3                          the man from toronto
# 4                                     five eyes
# 5                                       morbius
# 6                               the black phone
# 7                                      moonfall
# 8                               jackass forever
# 9                             death on the nile
# 10                                     marry me
# 11                                    uncharted
# 12                                    ambulance
# 13                                       rumble
# 16                                   the batman
# 18                     downton abbey: a new era
# 19                          the unbreakable boy
# 20  doctor strange in the multiverse of madness
# 21                                 bullet train
# 22                         sonic the hedgehog 2
# 23                                 the northman
# 24  fantastic beasts: the secrets of dumbledore
# 25                           the lost city of d
# 26                                 the bad guys
# 27      the unbearable weight of massive talent
# 28                       thor: love and thunder
# 29                                           65
# 30                      dc league of super-pets
# 32                            top gun: maverick
# 33                         john wick: chapter 4
# 40  Steve Carell Taraji P. Henson Michelle Yeoh Ky...
# 41  Lupita Nyong'o Letitia Wright Danai Gurira Rya...
# 42  Daniel Kaluuya Keke Palmer Steven Yeun Jordan ...
# 44  Harrison Ford Phoebe Waller-Bridge Mads Mikkel...
# 45  Dwayne Johnson Aldis Hodge Noah Centineo Jaume...
# 46  Gary Dauberman (director/screenplay) Lewis Pul...
# 49  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 50  Tom Cruise Ving Rhames Simon Pegg Christopher ...
# 51  Julia Roberts George Clooney Kaitlyn Dever Ol ...
# 52  Shameik Moore Jake Johnson Hailee Steinfeld Jo...
# 53  Jamie Lee Curtis Judy Greer Andi Matichak Davi...
# 54  Ezra Miller Michael Keaton Sasha Calle Andy Mu...
# 55  Brie Larson Teyonah Parris Iman Vellani Nia Da...
# 56  Vicky Jenson (director) Lauren Hynek Elizabeth...
# 57  Carey Mulligan Zoe Kazan Patricia Clarkson Mar...
# 59  Michael B. Jordan Tessa Thompson Phylicia Rash...
# 61  Sam Worthington Zoe Saldana Stephen Lang James...
# 62  Jason Momoa Amber Heard Patrick Wilson James W...
# 65  Brad Pitt Margot Robbie Katherine Waterston Da...

# %%
old_df = pd.read_csv('main_data.csv')

# %%
old_df
# Out:
#          director_name         actor_1_name       actor_2_name  \
# 0        John Lasseter            Tom Hanks          Tim Allen
# 1         Joe Johnston       Robin Williams      Jonathan Hyde
# 2        Howard Deutch       Walter Matthau        Jack Lemmon
# 3      Forest Whitaker      Whitney Houston     Angela Bassett
# 4        Charles Shyer         Steve Martin       Diane Keaton
# ...                ...                  ...                ...
# 40203   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 40204   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 40205   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 40206   Erwin brothers         Zachary Levi        Anna Paquin
# 40207       Joe Wright       Peter Dinklage      Haley Bennett
#
#                 actor_3_name                                     genres  \
# 0                Don Rickles                    Animation Comedy Family
# 1              Kirsten Dunst                   Adventure Fantasy Family
# 2                Ann-Margret                             Romance Comedy
# 3             Loretta Devine                       Comedy Drama Romance
# 4               Martin Short                                     Comedy
# ...                      ...                                        ...
# 40203  Yahya Abdul-Mateen II  Action Adventure Thriller Science Fiction
# 40204     Scarlett Johansson        Family Comedy Animation Drama Music
# 40205             Rhys Ifans              War Action Thriller Adventure
# 40206       Ser'Darius Blain                                      Drama
# 40207    Kelvin Harrison Jr.               Drama Comedy History Romance
#
#                                     movie_title  \
# 0                                     toy story
# 1                                       jumanji
# 2                              grumpier old men
# 3                             waiting to exhale
# 4                   father of the bride part ii
# ...                                         ...
# 40203                  the matrix resurrections
# 40204                                    sing 2
# 40205                            the king's man
# 40206  american underdog: the kurt warner story
# 40207                                    cyrano
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 40203  Keanu Reeves Carrie-Anne Moss Yahya Abdul-Mate...
# 40204  Matthew McConaughey Reese Witherspoon Scarlett...
# 40205  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 40206  Zachary Levi Anna Paquin Ser'Darius Blain Erwi...
# 40207  Peter Dinklage Haley Bennett Kelvin Harrison J...
#
# [40208 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#            director_name       actor_1_name    actor_2_name  \
# 0          John Lasseter          Tom Hanks       Tim Allen
# 1           Joe Johnston     Robin Williams   Jonathan Hyde
# 2          Howard Deutch     Walter Matthau     Jack Lemmon
# 3        Forest Whitaker    Whitney Houston  Angela Bassett
# 4          Charles Shyer       Steve Martin    Diane Keaton
# ...                  ...                ...             ...
# 40257     Maria Schrader     Carey Mulligan       Zoe Kazan
# 40258  Michael B. Jordan  Michael B. Jordan  Tessa Thompson
# 40259      James Cameron    Sam Worthington     Zoe Saldana
# 40260          James Wan        Jason Momoa     Amber Heard
# 40261    Damien Chazelle          Brad Pitt   Margot Robbie
#
#               actor_3_name                                     genres  \
# 0              Don Rickles                    Animation Comedy Family
# 1            Kirsten Dunst                   Adventure Fantasy Family
# 2              Ann-Margret                             Romance Comedy
# 3           Loretta Devine                       Comedy Drama Romance
# 4             Martin Short                                     Comedy
# ...                    ...                                        ...
# 40257    Patricia Clarkson                 Comedy Crime Drama Mystery
# 40258      Phylicia Rashad                               Drama Action
# 40259         Stephen Lang   Action Adventure Science Fiction Fantasy
# 40260       Patrick Wilson                   Adventure Action Fantasy
# 40261  Katherine Waterston  Action Adventure Science Fiction Thriller
#
#                         movie_title  \
# 0                         toy story
# 1                           jumanji
# 2                  grumpier old men
# 3                 waiting to exhale
# 4       father of the bride part ii
# ...                             ...
# 40257                      she said
# 40258                     creed iii
# 40259                      avatar 2
# 40260  aquaman and the lost kingdom
# 40261                       babylon
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 40257  Carey Mulligan Zoe Kazan Patricia Clarkson Mar...
# 40258  Michael B. Jordan Tessa Thompson Phylicia Rash...
# 40259  Sam Worthington Zoe Saldana Stephen Lang James...
# 40260  Jason Momoa Amber Heard Patrick Wilson James W...
# 40261  Brad Pitt Margot Robbie Katherine Waterston Da...
#
# [40262 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
